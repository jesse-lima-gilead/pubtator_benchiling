# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 132.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 22.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.6/436.6 kB 24.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.7/284.7 kB 39.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.8/381.8 kB 27.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 28.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 57.2 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install scikit-learn
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 12.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 15.7 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 10.4 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 31.8 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 MB 19.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 20.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 16.8 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Legends:
#
# - caps - Chunk with Annotations Prepended and Summary
# - cap - Chunk with Annotations Prepended and NO Summary
# - cais - Chunk with Annotations Inline and Summary
# - cai - Chunk with Annotations Inline and NO Summary
# - caas - Chunk with Annotations Appended and Summary
# - caa - Chunk with Annotations Appended and NO Summary

# %%
#### Prepended Annotations and Summary

chunk_caps = """
Summary:
The study found a significant association between PM2.5 air pollution levels and the incidence of EGFR-driven lung cancer across cohorts in England, South Korea, and Taiwan. Experiments in mouse models demonstrated that short-term PM2.5 exposure promotes the progression of EGFR-mutant lung cancer cells by triggering an inflammatory response mediated by macrophages and interleukin-1β (IL-1β). This results in a progenitor-like state in EGFR-mutant lung alveolar type II cells that fuels tumorigenesis. Deep mutational profiling of non-cancerous lung tissue samples from nearly 300 patients revealed frequent occurrences of activating driver mutations in EGFR (18% of samples) and KRAS (53% of samples). The findings support a tumor-promoting role for PM2.5 in EGFR-mutant lung epithelial cells and provide evidence that driver mutations exist in histologically normal lungs. Reducing air pollution exposure may help decrease lung cancer risk.

Annotations:
Text - GFR 
Type - Gene
NCBI Gene - 13649
Text - RAS 
Type - Gene
NCBI Gene - 16653
Text - mouse
Type - Species
NCBI Taxonomy - 10090
Text - EGFR
Type - Gene
NCBI Gene - 13649
Text - KRAS
Type - Gene
NCBI Gene - 16653

Text:
A complete understanding of how exposure to environmental substances promotes cancer formation is lacking. More than 70 years ago, tumorigenesis was proposed to occur in a two-step process: an initiating step that induces mutations in healthy cells, followed by a promoter step that triggers cancer development1. Here we propose that environmental particulate matter measuring ≤2.5 μm (PM2.5), known to be associated with lung cancer risk, promotes lung cancer by acting on cells that harbour pre-existing oncogenic mutations in healthy lung tissue. Focusing on EGFR-driven lung cancer, which is more common in never-smokers or light smokers, we found a significant association between PM2.5 levels and the incidence of lung cancer for 32,957 EGFR driven lung cancer cases in four within-country cohorts. Functional mouse models revealed that air pollutants cause an influx of macrophages into the lung and release of interleukin-1β. This process results in a progenitor-like cell state within EGFR mutant lung alveolar type II epithelial cells that fuels tumorigenesis. Ultradeep mutational profiling of histologically normal lung tissue from 295 individuals across 3 clinical cohorts revealed oncogenic EGFR and KRAS driver mutations in 18% and 53% of healthy tissue samples, respectively. These findings collectively support a tumour promoting role for PM2.5 air pollutants and provide impetus for public health policy initiatives to address air pollution to reduce disease burden.      
"""

#### Prepended Annotations and NO Summary

chunk_cap = """
Annotations:
Text - GFR 
Type - Gene
NCBI Gene - 13649
Text - RAS 
Type - Gene
NCBI Gene - 16653
Text - mouse
Type - Species
NCBI Taxonomy - 10090
Text - EGFR
Type - Gene
NCBI Gene - 13649
Text - KRAS
Type - Gene
NCBI Gene - 16653

Text:
A complete understanding of how exposure to environmental substances promotes cancer formation is lacking. More than 70 years ago, tumorigenesis was proposed to occur in a two-step process: an initiating step that induces mutations in healthy cells, followed by a promoter step that triggers cancer development1. Here we propose that environmental particulate matter measuring ≤2.5 μm (PM2.5), known to be associated with lung cancer risk, promotes lung cancer by acting on cells that harbour pre-existing oncogenic mutations in healthy lung tissue. Focusing on EGFR-driven lung cancer, which is more common in never-smokers or light smokers, we found a significant association between PM2.5 levels and the incidence of lung cancer for 32,957 EGFR driven lung cancer cases in four within-country cohorts. Functional mouse models revealed that air pollutants cause an influx of macrophages into the lung and release of interleukin-1β. This process results in a progenitor-like cell state within EGFR mutant lung alveolar type II epithelial cells that fuels tumorigenesis. Ultradeep mutational profiling of histologically normal lung tissue from 295 individuals across 3 clinical cohorts revealed oncogenic EGFR and KRAS driver mutations in 18% and 53% of healthy tissue samples, respectively. These findings collectively support a tumour promoting role for PM2.5 air pollutants and provide impetus for public health policy initiatives to address air pollution to reduce disease burden.
"""


#### Inline Annotations and Summary

chunk_cais = """
Summary:
The study found a significant association between PM2.5 air pollution levels and the incidence of EGFR-driven lung cancer across cohorts in England, South Korea, and Taiwan. Experiments in mouse models demonstrated that short-term PM2.5 exposure promotes the progression of EGFR-mutant lung cancer cells by triggering an inflammatory response mediated by macrophages and interleukin-1β (IL-1β). This results in a progenitor-like state in EGFR-mutant lung alveolar type II cells that fuels tumorigenesis. Deep mutational profiling of non-cancerous lung tissue samples from nearly 300 patients revealed frequent occurrences of activating driver mutations in EGFR (18% of samples) and KRAS (53% of samples). The findings support a tumor-promoting role for PM2.5 in EGFR-mutant lung epithelial cells and provide evidence that driver mutations exist in histologically normal lungs. Reducing air pollution exposure may help decrease lung cancer risk.

Text:
A complete understanding of how exposure to environmental substances promotes cancer formation is lacking. More than 70 years ago, tumorigenesis was proposed to occur in a two-step process: an initiating step that induces mutations in healthy cells, followed by a promoter step that triggers cancer development1. Here we propose that environmental particulate matter measuring ≤2.5 μm (PM2.5), known to be associated with lung cancer risk, promotes lung cancer by acting on cells that harbour pre-existing oncogenic mutations in healthy lung tissue. Focusing on EGFR << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-13649 >>-driven lung cancer, which is more common in never-smokers or light smokers, we found a significant association between PM2.5 levels and the incidence of lung cancer for 32,957 EGFR << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-13649 >> driven lung cancer cases in four within-country cohorts. Functional mouse << Type-Species, NCBI Label-NCBI Taxonomy, NCBI Id-10090 >> models revealed that air pollutants cause an influx of macrophages into the lung and release of interleukin-1β. This process results in a progenitor-like cell state within EGFR << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-13649 >> mutant lung alveolar type II epithelial cells that fuels tumorigenesis. Ultradeep mutational profiling of histologically normal lung tissue from 295 individuals across 3 clinical cohorts revealed oncogenic EGFR << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-13649 >> and KRAS << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-16653 >> driver mutations in 18% and 53% of healthy tissue samples, respectively. These findings collectively support a tumour promoting role for PM2.5 air pollutants and provide impetus for public health policy initiatives to address air pollution to reduce disease burden.
"""

#### Inline Annotations and NO Summary

chunk_cai = """
Text:
A complete understanding of how exposure to environmental substances promotes cancer formation is lacking. More than 70 years ago, tumorigenesis was proposed to occur in a two-step process: an initiating step that induces mutations in healthy cells, followed by a promoter step that triggers cancer development1. Here we propose that environmental particulate matter measuring ≤2.5 μm (PM2.5), known to be associated with lung cancer risk, promotes lung cancer by acting on cells that harbour pre-existing oncogenic mutations in healthy lung tissue. Focusing on EGFR << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-13649 >>-driven lung cancer, which is more common in never-smokers or light smokers, we found a significant association between PM2.5 levels and the incidence of lung cancer for 32,957 EGFR << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-13649 >> driven lung cancer cases in four within-country cohorts. Functional mouse << Type-Species, NCBI Label-NCBI Taxonomy, NCBI Id-10090 >> models revealed that air pollutants cause an influx of macrophages into the lung and release of interleukin-1β. This process results in a progenitor-like cell state within EGFR << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-13649 >> mutant lung alveolar type II epithelial cells that fuels tumorigenesis. Ultradeep mutational profiling of histologically normal lung tissue from 295 individuals across 3 clinical cohorts revealed oncogenic EGFR << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-13649 >> and KRAS << Type-Gene, NCBI Label-NCBI Gene, NCBI Id-16653 >> driver mutations in 18% and 53% of healthy tissue samples, respectively. These findings collectively support a tumour promoting role for PM2.5 air pollutants and provide impetus for public health policy initiatives to address air pollution to reduce disease burden.
"""

# %%
from transformers import AutoTokenizer, AutoModel
import torch

# Function to get embeddings
def get_embeddings(model_name, text):
    # Load tokenizer and model
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)
    
    # Tokenize and convert to input IDs
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    
    # Get model output
    with torch.no_grad():
        outputs = model(**inputs)
    
    # Mean pooling of the last hidden state
    embeddings = outputs.last_hidden_state.mean(dim=1)
    return embeddings

# %% [markdown]
# # Generating Embeddings using Multiple Models

# %%
chunks_variations = [chunk_caps, chunk_cap, chunk_cais, chunk_cai]
bio_gpt_embeddings = ["bio_gpt_embeddings_caps", "bio_gpt_embeddings_cap", "bio_gpt_embeddings_cais", "bio_gpt_embeddings_cai"]
bio_bert_embeddings = ["bio_bert_embeddings_caps", "bio_bert_embeddings_cap", "bio_bert_embeddings_cais", "bio_bert_embeddings_cai"]

# %% [markdown]
# ## BioGPT

# %%
# Generate embeddings 
model_name = "BioGPT"
model_path = "microsoft/biogpt"

for i in range(len(chunks_variations)):
    chunk = chunks_variations[i]
    print(f"Generating embeddings using {model_name}...")
    bio_gpt_embeddings[i] = get_embeddings(model_path, chunk)
    #print(f"Embeddings from {model_name}: {bio_gpt_embeddings}")
# Out:
# Generating embeddings using BioGPT...
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Generating embeddings using BioGPT...
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Generating embeddings using BioGPT...
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Generating embeddings using BioGPT...
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
len(bio_gpt_embeddings[0])
# Out:
# 1024

# %%
print(bio_gpt_embeddings[0][0])
# Out:
# tensor(-0.7412)

# %% [markdown]
# ## BioBERT

# %%
# Generate embeddings 
model_name = "BioBERT"
model_path = "dmis-lab/biobert-v1.1"

for i in range(len(chunks_variations)):
    chunk = chunks_variations[i]
    print(f"Generating embeddings using {model_name}...")
    bio_bert_embeddings[i] = get_embeddings(model_path, chunk)
    #print(f"Embeddings from {model_name}: {bio_gpt_embeddings}")
# Out:
# Generating embeddings using BioBERT...
# Generating embeddings using BioBERT...
# Generating embeddings using BioBERT...
# Generating embeddings using BioBERT...

# %%
print(bio_bert_embeddings[0])
# Out:
# tensor([[ 2.5446e-01, -1.2669e-01, -1.9011e-01, -1.8289e-02,  2.9667e-02,
#           2.2483e-02, -1.6527e-01,  1.6997e-01,  1.4812e-01, -1.2732e-01,
#           2.3676e-01,  1.6962e-01, -2.3807e-01,  2.1806e-01, -2.1594e-01,
#          -1.4594e-01,  5.3442e-02, -3.9743e-02, -1.8265e-01, -1.7337e-02,
#          -2.0237e-01,  4.9092e-02, -1.8190e-01,  5.3052e-02,  6.1317e-02,
#          -5.6511e-02, -3.7748e-02,  4.6900e-01, -6.1703e-02,  3.0310e-01,
#          -2.1478e-02, -2.0688e-01,  1.7624e-02,  6.7918e-02,  9.3314e-02,
#          -2.1162e-03, -8.1720e-02,  1.6158e-01, -1.2560e-01,  2.3604e-01,
#           6.0071e-02, -2.8637e-02,  1.2253e-01, -8.3056e-02, -1.0129e-01,
#          -2.4765e-01, -2.4254e-01, -5.4797e-02, -2.9350e-01,  6.6176e-02,
#           6.5752e-02,  3.0724e-01,  2.2702e-01,  5.8525e-02,  1.6347e-01,
#          -2.7591e-01,  2.6706e-02,  4.4465e-02,  4.5085e-02,  1.8110e-01,
#          -1.1226e-01, -1.0274e-01,  2.5151e-01,  1.6176e-01, -1.4179e-02,
# ...

# %%
print(len(bio_bert_embeddings[0]))
# Out:
# 1

# %%
print(bio_bert_embeddings[0][0])
# Out:
# tensor([ 2.5446e-01, -1.2669e-01, -1.9011e-01, -1.8289e-02,  2.9667e-02,
#          2.2483e-02, -1.6527e-01,  1.6997e-01,  1.4812e-01, -1.2732e-01,
#          2.3676e-01,  1.6962e-01, -2.3807e-01,  2.1806e-01, -2.1594e-01,
#         -1.4594e-01,  5.3442e-02, -3.9743e-02, -1.8265e-01, -1.7337e-02,
#         -2.0237e-01,  4.9092e-02, -1.8190e-01,  5.3052e-02,  6.1317e-02,
#         -5.6511e-02, -3.7748e-02,  4.6900e-01, -6.1703e-02,  3.0310e-01,
#         -2.1478e-02, -2.0688e-01,  1.7624e-02,  6.7918e-02,  9.3314e-02,
#         -2.1162e-03, -8.1720e-02,  1.6158e-01, -1.2560e-01,  2.3604e-01,
#          6.0071e-02, -2.8637e-02,  1.2253e-01, -8.3056e-02, -1.0129e-01,
#         -2.4765e-01, -2.4254e-01, -5.4797e-02, -2.9350e-01,  6.6176e-02,
#          6.5752e-02,  3.0724e-01,  2.2702e-01,  5.8525e-02,  1.6347e-01,
#         -2.7591e-01,  2.6706e-02,  4.4465e-02,  4.5085e-02,  1.8110e-01,
#         -1.1226e-01, -1.0274e-01,  2.5151e-01,  1.6176e-01, -1.4179e-02,
# ...

# %% [markdown]
# ## MedCPT

# %% [markdown]
# # Retrival

# %%
user_query = "lung cancer risk from air pollution"

query_embeddings_bio_gpt = get_embeddings("microsoft/biogpt", user_query)
query_embeddings_bio_bert = get_embeddings("dmis-lab/biobert-v1.1", user_query)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
# Cosine similarity
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity between query and text embeddings
bio_gpt_similarities = ["bio_gpt_similarities_caps", "bio_gpt_similarities_cap", "bio_gpt_similarities_cais", "bio_gpt_similarities_cai"]
bio_bert_similarities = ["bio_bert_similarities_caps", "bio_bert_similarities_cap", "bio_bert_similarities_cais", "bio_bert_similarities_cai"]

for i in range(len(bio_gpt_embeddings)):
    bio_gpt_embedding = bio_gpt_embeddings[i]
    bio_gpt_similarities[i] = cosine_similarity(query_embeddings_bio_gpt, bio_gpt_embedding)

for i in range(len(bio_bert_embeddings)):
    bio_bert_embedding = bio_bert_embeddings[i]
    bio_bert_similarities[i] = cosine_similarity(query_embeddings_bio_bert, bio_bert_embedding)

print(f"Similarity between query and text using BioGPT: {bio_gpt_similarities}")

print(f"Similarity between query and text using BioBERT: {bio_bert_similarities}")
# Out:
# Similarity between query and text using BioGPT: [array([[0.5464252]], dtype=float32), array([[0.5596143]], dtype=float32), array([[0.52441794]], dtype=float32), array([[0.53178906]], dtype=float32)]
# Similarity between query and text using BioBERT: [array([[0.8187957]], dtype=float32), array([[0.8227719]], dtype=float32), array([[0.81927997]], dtype=float32), array([[0.8007251]], dtype=float32)]

# %%
# Generate initial similarity scores using BioGPT/BioBERT
similarity_scores = similarity_bio_bert[0][0]
threshold = 0.75  # Define a threshold based on experimentation

true_labels = (similarity_scores >= threshold).astype(int)

print(true_labels)
0
# Out:
# 1
